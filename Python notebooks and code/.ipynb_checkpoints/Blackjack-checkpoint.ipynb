# %%
import gym
import numpy as np
from collections import defaultdict
import sys

# %%
env = gym.make("Blackjack-v0")

# %%
env

# %% [markdown]
# Each state is a 3-tuple of:
# - the player's current sum $\in \{0, 1, \ldots, 31\}$,
# - the dealer's face up card $\in \{1, \ldots, 10\}$, and
# - whether or not the player has a usable ace (`no` $=0$, `yes` $=1$).
#
# The agent has two potential actions:
#
# ```
#     STICK = 0
#     HIT = 1
# ```
#
# The rewards go like 0 for all non terminal steps and +1,-1 depending on the result of the game

# %%
#observation is a tuple of the current sum of the player, the dealer's face up card, and a bool whether the ace if present is useable or not
env.observation_space
# Out:
# Tuple(Discrete(32), Discrete(11), Discrete(2))

# %%
env.action_space
# Out:
# Discrete(2)

# %%
print(env.observation_space.sample())
# Out:
# (12, 5, 0)

# %%
print(env.action_space.sample())
# Out:
# 1

# %%
#equiproabable policy

for episode_i in range(3):
    print("episode: ",episode_i)
    state = env.reset()
    print(state)
    while True:
        action = env.action_space.sample()
        print(action)
        state, reward, done, info = env.step(action)
        print(state,reward)
        if done:
            print("End game")
            if reward>0:
                print("User won the game")
            else:
                print("Dealer won the game")
            print()
            break
# Out:
# episode:  0
# (15, 10, False)
# 0
# (15, 10, False) -1.0
# End game
# Dealer won the game
#
# episode:  1
# (13, 10, False)
# 0
# (13, 10, False) -1.0
# End game
# Dealer won the game
#
# episode:  2
# (14, 1, False)
# 1
# (24, 1, False) -1
# End game
# Dealer won the game

# %%
def generate_episode_from_limit_stochastic(bj_env):
    state = bj_env.reset()
    episode = []
    probs = [0,0]
    while True:
        if state[0]>=18:
            probs = [0.8,0.2]
        elif state[1]<18:
            probs = [0.2,0.8]
        action = np.random.choice(np.arange(2),p=probs)
        new_state,reward,done,info = bj_env.step(action)
        episode.append((state,action,reward))
        state = new_state
        if done:
            return episode

# %%
generate_episode_from_limit_stochastic(env)
# Out:
# [((16, 7, False), 0, -1.0)]

# %%
def gen_episode_stochastic(bj_env):
    
    episode = []
    state = bj_env.reset()
    probs = [0,0]
    while True:
        if state[0]>18:
            probs = [0.8,0.2]
        else:
            probs = [0.2,0.8]
        action = np.random.choice(np.arange(2),p=probs)
        state_n, reward, done, info = bj_env.step(action)
        episode.append((state,action,reward))
        state = state_n
        if done:
            return episode

# %%
for episode_i in range(3):
    print(gen_episode_stochastic(env))
# Out:
# [((11, 10, False), 1, 0), ((21, 10, False), 0, 1.0)]
# [((10, 1, False), 0, -1.0)]
# [((12, 1, False), 0, -1.0)]

# %%
def gen_episode_det(bj_env):
    
    episode = []
    state = bj_env.reset()
    
    while True:
        if state[0]>18:
            action = 0
        else:
            action = 1
        next_state,reward,done,info = bj_env.step(action)
        episode.append((state,action,reward))
        state = next_state
        if done:
            return episode

# %%
for episode_i in range(3):
    print(gen_episode_det(env))
# Out:
# [((15, 10, False), 1, 0), ((21, 10, False), 0, 1.0)]
# [((6, 7, False), 1, 0), ((11, 7, False), 1, 0), ((14, 7, False), 1, -1)]
# [((18, 5, True), 1, 0), ((18, 5, False), 1, 0), ((19, 5, False), 0, 1.0)]

# %%
X = defaultdict(lambda:np.zeros(env.action_space.n))

# %%
N = defaultdict(lambda:np.zeros(env.action_space.n))

# %%
print(N)
# Out:
# defaultdict(<function <lambda> at 0x1047e7598>, {})

# %%
returns_sum = defaultdict(lambda: np.zeros(env.action_space.n))

# %%
print(returns_sum)
# Out:
# defaultdict(<function <lambda> at 0x1a13811840>, {})

# %%
#For black jack, evmc and fvmc are equivalent since a state generally won't repeat in an episode.

def evmc_q_table(num_episodes,env,gamma=1):
    returns_sum = defaultdict(lambda:np.zeros(env.action_space.n))
    N = defaultdict(lambda:np.zeros(env.action_space.n))
    Q = defaultdict(lambda:np.zeros(env.action_space.n))

    for episode_i in range(num_episodes):
        episode = gen_episode_stochastic(env)
        states,actions,rewards = zip(*episode)
        for index,item in enumerate(episode):
            rewards = np.array(rewards)
            discounting = np.array([gamma**i for i in range(len(rewards))])
#             print(discounting)
#             print(rewards[index:])
            returns_sum[item[0]][item[1]]+=np.sum(np.array(discounting*rewards))
            N[item[0]][item[1]]+=1
            Q[item[0]][item[1]] = returns_sum[item[0]][item[1]]/N[item[0]][item[1]]
#     print(returns_sum.keys())
#     print(returns_sum.values())
#     print()
#     for k in returns_sum.keys():
#         print(returns_sum[k],end=" ")
#         print(N[k])
#         print()
    
#     for k in returns_sum.keys():
#             Q[k] = returns_sum[k]/N[k]
    return Q

# %%
def discounting_factor(index,n,gamma=1):
    return np.array([gamma**i for i in range(n-index)])

# %%
discounting_factor(3,10,0.2)
# Out:
# array([1.0e+00, 2.0e-01, 4.0e-02, 8.0e-03, 1.6e-03, 3.2e-04, 6.4e-05])

# %%
def ev_mc(num_episodes,env,gen=generate_episode_from_limit_stochastic,gamma=1):
    
    n = {}
    q = {}
    r = {}
    for episode_i in range(num_episodes):
        episode = generate_episode_from_limit_stochastic(env)
        states,actions,rewards = zip(*episode)
        for index,item in enumerate(episode):
            if item[0] not in n:
                n[item[0]] = np.zeros(env.action_space.n)
                r[item[0]] = np.zeros(env.action_space.n)
                q[item[0]] = np.zeros(env.action_space.n)
            n[item[0]][item[1]]+=1
            r[item[0]][item[1]]+=(discounting_factor(index,len(episode),gamma)*np.array(rewards[index:])).sum()
        q[item[0]][item[1]] = r[item[0]][item[1]]/n[item[0]][item[1]]
    return q

# %%
ev_mc(50000,env)
# Out:
# {(12, 10, False): array([-0.59006211, -0.52494577]),
#  (17, 8, False): array([-0.53947368, -0.62834225]),
#  (18, 8, False): array([ 0.08430233, -0.64444444]),
#  (11, 5, False): array([-0.26530612,  0.        ]),
#  (21, 5, False): array([ 0.90419162, -1.        ]),
#  (14, 4, False): array([-0.22580645, -0.57910448]),
#  (18, 4, False): array([ 0.08625337, -0.75      ]),
#  (20, 8, False): array([ 0.79423868, -0.968     ]),
#  (17, 3, False): array([-0.08823529, -0.55313351]),
#  (14, 3, True): array([0., 0.]),
#  (14, 3, False): array([-0.13580247, -0.43989071]),
#  (16, 3, False): array([-0.39473684, -0.49874055]),
#  (13, 9, False): array([-0.64705882, -0.46827795]),
#  (19, 2, True): array([0.47761194, 0.        ]),
#  (14, 8, True): array([-0.71428571,  0.        ]),
#  (17, 8, True): array([-0.14285714,  0.        ]),
#  (14, 7, True): array([-1.,  0.]),
#  (15, 7, True): array([-0.33333333,  0.        ]),
#  (13, 7, True): array([0.55555556, 0.        ]),
#  (14, 9, True): array([-0.75,  0.  ]),
#  (18, 8, True): array([0.30909091, 0.        ]),
#  (5, 2, False): array([0.2, 0. ]),
#  (6, 6, False): array([-0.06666667,  0.        ]),
#  (20, 8, True): array([0.67857143, 0.        ]),
#  (8, 5, False): array([0.14285714, 0.        ]),
#  (5, 4, False): array([-0.77777778,  0.        ]),
#  (17, 9, True): array([-0.46666667,  0.        ]),
#  (5, 8, False): array([-0.77777778,  0.        ]),
#  (19, 6, True): array([0.51612903, 0.        ]),
#  (19, 7, True): array([0.41818182, 0.        ]),
#  (13, 6, True): array([-0.53846154,  0.        ]),
#  (12, 6, True): array([-0.66666667,  0.        ]),
#  (20, 5, True): array([0.6, 0. ]),
#  (13, 8, True): array([-0.33333333,  0.        ]),
#  (5, 7, False): array([0.2, 0. ]),
#  (4, 3, False): array([-0.2,  0. ]),
#  (19, 1, True): array([-0.14285714,  0.        ]),
#  (9, 1, False): array([-0.85,  0.  ]),
#  (4, 10, False): array([-0.5,  0. ]),
#  (7, 7, False): array([-0.57894737,  0.        ]),
#  (13, 9, True): array([-0.81818182,  0.        ]),
#  (4, 7, False): array([-0.66666667,  0.        ]),
#  (12, 8, True): array([0.2, 0. ]),
#  (4, 2, False): array([-0.5,  0. ]),
#  (12, 1, True): array([-0.33333333,  0.        ]),
#  (4, 5, False): array([-0.5,  0. ]),
#  (14, 1, True): array([-0.75,  0.  ]),
#  (15, 1, True): array([-0.63636364,  0.        ]),
#  (20, 1, True): array([0.45, 0.  ]),
#  (4, 1, False): array([-1.,  0.])}

# %%
Q_table = evmc_q_table(500000,env,1)
Q_table
# Out:
# defaultdict(<function __main__.evmc_q_table.<locals>.<lambda>()>,
#             {(11, 3, False): array([-0.19907407, -0.05413271]),
#              (16, 3, False): array([-0.29032258, -0.61918438]),
#              (12, 1, False): array([-0.75615213, -0.65523307]),
#              (17, 1, False): array([-0.62921348, -0.74083264]),
#              (15, 6, False): array([-0.14835787, -0.55508475]),
#              (17, 3, True): array([-0.01840491, -0.30417495]),
#              (14, 3, False): array([-0.225     , -0.54915536]),
#              (12, 9, False): array([-0.5159516, -0.4886231]),
#              (13, 9, False): array([-0.53970081, -0.51422135]),
#              (14, 9, False): array([-0.50845547, -0.56087824]),
#              (20, 9, False): array([ 0.74863495, -0.88342585]),
#              (18, 9, False): array([-0.17272727, -0.69059406]),
#              (10, 10, False): array([-0.54724677, -0.23942677]),
#              (20, 10, False): array([ 0.43353175, -0.8837535 ]),
#              (14, 10, False): array([-0.59613746, -0.61717428]),
#              (21, 10, True): array([ 0.89484979, -0.17160775]),
#              (19, 10, False): array([-0.01279772, -0.78447045]),
#              (15, 10, False): array([-0.59756772, -0.65128845]),
#              (21, 10, False): array([ 0.8836187, -1.       ]),
#              (9, 1, False): array([-0.76208178, -0.51732474]),
#              (7, 6, False): array([-0.08139535, -0.31147541]),
#              (12, 7, True): array([-0.63265306, -0.08374384]),
#              (12, 1, True): array([-0.85714286, -0.35294118]),
#              (16, 5, True): array([-0.31623932, -0.20645161]),
#              (5, 5, False): array([-0.25641026, -0.34173669]),
#              (5, 1, False): array([-0.58139535, -0.58583106]),
#              (13, 5, True): array([-0.16190476, -0.09322034]),
#              (6, 2, False): array([-0.25862069, -0.40398551]),
#              (8, 1, False): array([-0.71945701, -0.62345679]),
#              (14, 8, True): array([-0.61904762, -0.21686747]),
#              (14, 7, True): array([-0.56989247, -0.16853933]),
#              (15, 4, True): array([-0.28571429, -0.09839817]),
#              (14, 2, True): array([-0.35294118, -0.16202532]),
#              (9, 4, False): array([-0.37341772, -0.16474465]),
#              (13, 9, True): array([-0.62352941, -0.11315789]),
#              (17, 9, True): array([-0.37931034, -0.26205451]),
#              (13, 3, True): array([-0.33333333, -0.06157635]),
#              (7, 5, False): array([-0.04186047, -0.38519448]),
#              (4, 10, False): array([-0.51955307, -0.50262467]),
#              (12, 5, True): array([-0.02325581,  0.00540541]),
#              (12, 4, True): array([-0.18181818, -0.16853933]),
#              (18, 1, True): array([-0.32894737, -0.51595745]),
#              (15, 8, True): array([-0.49565217, -0.21296296]),
#              (12, 10, True): array([-0.55445545, -0.28436658]),
#              (13, 10, True): array([-0.56430446, -0.30612245]),
#              (10, 8, False): array([-0.54736842, -0.06185567]),
#              (12, 6, True): array([-0.15555556,  0.10344828]),
#              (4, 7, False): array([-0.38461538, -0.32820513]),
#              (18, 2, True): array([ 0.15441176, -0.25801012]),
#              (16, 8, True): array([-0.51219512, -0.20638298]),
#              (4, 5, False): array([-0.06666667, -0.325     ]),
#              (14, 1, True): array([-0.75238095, -0.46683047]),
#              (5, 7, False): array([-0.48      , -0.44502618]),
#              (16, 2, True): array([-0.35185185, -0.09333333]),
#              (18, 4, True): array([ 0.05228758, -0.35440932]),
#              (17, 2, True): array([-0.06766917, -0.29158111]),
#              (16, 9, True): array([-0.47457627, -0.25757576]),
#              (12, 2, True): array([-0.11111111, -0.16860465]),
#              (4, 3, False): array([-0.28301887, -0.28125   ]),
#              (4, 9, False): array([-0.58333333, -0.43386243]),
#              (4, 6, False): array([-0.26315789, -0.4368932 ]),
#              (4, 2, False): array([-0.44680851, -0.40372671]),
#              (14, 3, True): array([-0.14563107, -0.16666667]),
#              (12, 8, True): array([-0.74074074, -0.22580645])})

# %%
len(list(Q_table.keys()))
# Out:
# 280

# %%
a1 = np.array([[20,10],[30,25]])
a2 = np.array([[5,2],[6,5]])
a3 = a1/a2

a3
# Out:
# array([[4., 5.],
#        [5., 5.]])

# %%
def gen_episode(env,policy):
    state = env.reset()
    action = 0
    episode = []
    while True:
        if state not in policy:
            if state[0]>18:
                probs = [0.8,0.2]
            else:
                probs = [0.2,0.8]
            action = np.random.choice(np.arange(2),p = probs)
        else:
            action = policy[state]
        new_state, reward, done, info = env.step(action)
        episode.append((state,action,reward))
        state = new_state
        if done:
            return episode
        
def update_q(episode,alpha,q,gamma):
    
    states,actions,rewards = zip(*episode)
    for index,item in enumerate(episode):
        reward = ((discounting_factor(index,len(episode),gamma))*rewards[index:]).sum()
        if item[0] not in q:
            q[item[0]] = np.zeros(env.action_space.n)
        q[item[0]][item[1]] = q[item[0]][item[1]]+alpha*(reward-q[item[0]][item[1]])
    return q

# %%
def update_p(env,Q_table,epsilon,probs):
    nA = env.action_space.n
    greedy = (1-epsilon)+(epsilon)/nA
    non_greedy = (epsilon)/nA
    
    for state in Q_table:
        if state not in probs:
            probs[state] = np.zeros(env.action_space.n)
        max_index = np.where(Q_table[state]==max(Q_table[state]))
        probs[state][max_index] = greedy
        for j in range(len(Q_table[state])):
            if max_index==j:
                continue
            else:
                probs[state][j] = non_greedy
    return probs

# %%
def update_policy(probs):
    policy = {}
    
    for state in probs:
        policy[state] = np.random.choice(np.arange(2),p=list(probs[state]))
    return policy

# %%
policy = {}
q = {}
episode = gen_episode(env,policy)
episode

Q_table = update_q(episode,0.2,q,1)
Q_table

probs = {}

probs = update_p(env,Q_table,1,probs)
probs

policy = update_policy(probs)

policy
# Out:
# {(15, 10, False): 0}

# %%
def mc_control(env,num_episodes,alpha,gamma=1):
    
    Q_table = {}
    policy = {}
    probs = {}
    epsilon = 1
    for episode_i in range(num_episodes):
        episode = gen_episode(env,policy)
        Q_table = update_q(episode,alpha,Q_table,gamma)
        probs = update_p(env,Q_table,epsilon,probs)
        policy = update_policy(probs)
        
    return policy, Q_table

# %%
policy, Q_table = mc_control(env,5000,0.6)

# %%
policy, Q_table
# Out:
# ({(20, 10, False): 1,
#   (8, 6, False): 0,
#   (16, 6, False): 0,
#   (21, 6, False): 1,
#   (14, 7, False): 0,
#   (21, 7, False): 0,
#   (11, 10, False): 1,
#   (21, 10, False): 1,
#   (15, 10, False): 1,
#   (16, 10, False): 1,
#   (20, 7, False): 1,
#   (8, 10, False): 0,
#   (20, 2, False): 0,
#   (13, 10, False): 0,
#   (20, 8, False): 1,
#   (15, 2, False): 1,
#   (12, 5, False): 1,
#   (16, 2, False): 0,
#   (13, 7, False): 0,
#   (16, 7, False): 1,
#   (12, 10, False): 1,
#   (9, 7, False): 0,
#   (11, 6, False): 1,
#   (12, 6, False): 1,
#   (9, 4, False): 0,
#   (19, 4, False): 1,
#   (19, 10, False): 0,
#   (17, 3, True): 1,
#   (13, 3, False): 0,
#   (16, 3, False): 0,
#   (13, 2, False): 1,
#   (21, 2, False): 1,
#   (11, 2, False): 1,
#   (14, 4, False): 0,
#   (8, 2, False): 1,
#   (18, 2, False): 1,
#   (17, 10, False): 0,
#   (15, 3, False): 1,
#   (20, 3, False): 1,
#   (10, 5, False): 0,
#   (17, 10, True): 0,
#   (18, 7, False): 1,
#   (7, 10, False): 0,
#   (18, 10, True): 0,
#   (18, 10, False): 1,
#   (15, 5, False): 0,
#   (16, 5, False): 0,
#   (17, 5, False): 1,
#   (7, 3, False): 1,
#   (17, 3, False): 0,
#   (21, 10, True): 0,
#   (17, 6, False): 0,
#   (18, 6, False): 1,
#   (8, 7, False): 1,
#   (11, 1, False): 1,
#   (18, 1, False): 1,
#   (9, 10, False): 0,
#   (13, 4, False): 1,
#   (19, 6, False): 1,
#   (12, 9, False): 0,
#   (16, 9, False): 0,
#   (20, 9, False): 1,
#   (13, 2, True): 1,
#   (5, 10, False): 0,
#   (6, 7, False): 1,
#   (19, 2, False): 0,
#   (13, 1, False): 1,
#   (21, 2, True): 0,
#   (8, 1, False): 0,
#   (16, 1, False): 1,
#   (18, 5, False): 0,
#   (14, 3, False): 0,
#   (21, 3, False): 0,
#   (8, 9, False): 1,
#   (18, 9, False): 1,
#   (20, 6, False): 1,
#   (7, 7, False): 1,
#   (17, 7, False): 0,
#   (5, 4, False): 0,
#   (11, 4, False): 0,
#   (16, 4, False): 1,
#   (20, 4, False): 0,
#   (14, 8, False): 1,
#   (21, 8, False): 0,
#   (13, 8, False): 0,
#   (19, 1, False): 1,
#   (12, 2, False): 0,
#   (11, 7, False): 0,
#   (21, 7, True): 1,
#   (12, 1, False): 1,
#   (15, 4, False): 0,
#   (17, 4, False): 1,
#   (21, 4, False): 0,
#   (8, 5, False): 0,
#   (12, 8, False): 1,
#   (21, 3, True): 1,
#   (21, 4, True): 1,
#   (17, 8, False): 0,
#   (12, 9, True): 0,
#   (15, 9, True): 1,
#   (15, 9, False): 0,
#   (12, 7, False): 0,
#   (17, 1, False): 0,
#   (11, 8, False): 0,
#   (4, 10, False): 1,
#   (10, 6, False): 0,
#   (7, 1, False): 1,
#   (20, 1, False): 0,
#   (9, 2, False): 0,
#   (10, 2, False): 0,
#   (17, 2, False): 1,
#   (6, 10, False): 1,
#   (14, 6, False): 0,
#   (13, 4, True): 0,
#   (17, 9, True): 0,
#   (13, 9, False): 0,
#   (14, 1, False): 1,
#   (7, 4, False): 1,
#   (19, 5, False): 1,
#   (11, 3, False): 1,
#   (11, 5, False): 1,
#   (14, 5, False): 1,
#   (21, 9, True): 1,
#   (7, 8, False): 1,
#   (10, 8, False): 1,
#   (13, 6, False): 0,
#   (19, 10, True): 0,
#   (20, 5, False): 0,
#   (18, 7, True): 0,
#   (20, 10, True): 0,
#   (14, 9, True): 0,
#   (14, 9, False): 1,
#   (19, 9, False): 1,
#   (13, 5, False): 1,
#   (6, 2, False): 0,
#   (18, 3, False): 1,
#   (10, 1, False): 0,
#   (15, 1, False): 0,
#   (9, 9, False): 1,
#   (11, 9, False): 0,
#   (17, 9, False): 1,
#   (19, 8, True): 0,
#   (14, 10, False): 1,
#   (14, 2, False): 1,
#   (20, 2, True): 1,
#   (6, 4, False): 0,
#   (18, 8, False): 0,
#   (19, 8, False): 1,
#   (15, 6, False): 1,
#   (9, 5, False): 1,
#   (19, 6, True): 1,
#   (21, 6, True): 0,
#   (6, 1, False): 1,
#   (21, 8, True): 1,
#   (16, 8, False): 1,
#   (7, 6, False): 0,
#   (16, 1, True): 1,
#   (18, 1, True): 1,
#   (21, 5, False): 1,
#   (10, 3, False): 1,
#   (18, 8, True): 1,
#   (6, 9, False): 0,
#   (14, 10, True): 1,
#   (15, 8, False): 0,
#   (12, 4, False): 1,
#   (18, 4, False): 1,
#   (7, 5, False): 0,
#   (18, 2, True): 1,
#   (6, 6, False): 1,
#   (9, 8, False): 1,
#   (21, 1, False): 1,
#   (9, 6, False): 0,
#   (18, 6, True): 1,
#   (14, 8, True): 1,
#   (16, 4, True): 0,
#   (7, 2, False): 1,
#   (21, 1, True): 1,
#   (8, 4, False): 0,
#   (19, 4, True): 1,
#   (13, 10, True): 1,
#   (16, 5, True): 1,
#   (12, 3, True): 1,
#   (12, 3, False): 1,
#   (5, 3, False): 0,
#   (14, 6, True): 1,
#   (21, 5, True): 1,
#   (19, 7, False): 1,
#   (18, 5, True): 1,
#   (16, 2, True): 1,
#   (9, 3, False): 0,
#   (19, 3, False): 1,
#   (5, 8, False): 1,
#   (16, 8, True): 1,
#   (14, 2, True): 0,
#   (15, 7, False): 1,
#   (4, 8, False): 1,
#   (6, 3, False): 1,
#   (17, 2, True): 0,
#   (20, 3, True): 0,
#   (12, 7, True): 0,
#   (15, 7, True): 1,
#   (15, 10, True): 0,
#   (5, 2, False): 0,
#   (15, 5, True): 1,
#   (5, 9, False): 1,
#   (18, 3, True): 1,
#   (16, 10, True): 0,
#   (15, 2, True): 1,
#   (9, 1, False): 1,
#   (10, 10, False): 0,
#   (20, 1, True): 1,
#   (18, 9, True): 0,
#   (20, 9, True): 1,
#   (20, 7, True): 0,
#   (17, 1, True): 0,
#   (6, 8, False): 0,
#   (14, 4, True): 1,
#   (5, 7, False): 1,
#   (16, 7, True): 1,
#   (5, 6, False): 0,
#   (19, 5, True): 1,
#   (13, 5, True): 0,
#   (19, 2, True): 0,
#   (10, 4, False): 0,
#   (15, 4, True): 0,
#   (21, 9, False): 1,
#   (6, 5, False): 1,
#   (19, 3, True): 1,
#   (14, 3, True): 0,
#   (10, 9, False): 1,
#   (10, 7, False): 0,
#   (17, 7, True): 1,
#   (13, 3, True): 0,
#   (4, 9, False): 0,
#   (20, 5, True): 0,
#   (16, 3, True): 1,
#   (4, 6, False): 1,
#   (4, 2, False): 0},
#  {(20, 10, False): array([-1., -1.]),
#   (8, 6, False): array([-1.,  1.]),
#   (16, 6, False): array([-1., -1.]),
#   (21, 6, False): array([ 1., -1.]),
#   (14, 7, False): array([-1., -1.]),
#   (21, 7, False): array([ 0., -1.]),
#   (11, 10, False): array([-1.,  1.]),
#   (21, 10, False): array([ 1., -1.]),
#   (15, 10, False): array([-1., -1.]),
#   (16, 10, False): array([ 1., -1.]),
#   (20, 7, False): array([-1., -1.]),
#   (8, 10, False): array([-1., -1.]),
#   (20, 2, False): array([-1., -1.]),
#   (13, 10, False): array([-1., -1.]),
#   (20, 8, False): array([1., 1.]),
#   (15, 2, False): array([ 1., -1.]),
#   (12, 5, False): array([ 1., -1.]),
#   (16, 2, False): array([ 1., -1.]),
#   (13, 7, False): array([ 1., -1.]),
#   (16, 7, False): array([-1., -1.]),
#   (12, 10, False): array([-1., -1.]),
#   (9, 7, False): array([-1., -1.]),
#   (11, 6, False): array([ 1., -1.]),
#   (12, 6, False): array([1., 1.]),
#   (9, 4, False): array([ 0., -1.]),
#   (19, 4, False): array([-1., -1.]),
#   (19, 10, False): array([-1., -1.]),
#   (17, 3, True): array([-1.,  1.]),
#   (13, 3, False): array([-1.,  1.]),
#   (16, 3, False): array([-1., -1.]),
#   (13, 2, False): array([-1., -1.]),
#   (21, 2, False): array([ 1., -1.]),
#   (11, 2, False): array([ 1., -1.]),
#   (14, 4, False): array([-1., -1.]),
#   (8, 2, False): array([-1., -1.]),
#   (18, 2, False): array([-1., -1.]),
#   (17, 10, False): array([-1.,  1.]),
#   (15, 3, False): array([-1.,  1.]),
#   (20, 3, False): array([ 1., -1.]),
#   (10, 5, False): array([-1.,  1.]),
#   (17, 10, True): array([ 1., -1.]),
#   (18, 7, False): array([ 0., -1.]),
#   (7, 10, False): array([-1.,  1.]),
#   (18, 10, True): array([-1., -1.]),
#   (18, 10, False): array([ 1., -1.]),
#   (15, 5, False): array([ 1., -1.]),
#   (16, 5, False): array([-1., -1.]),
#   (17, 5, False): array([ 1., -1.]),
#   (7, 3, False): array([-1., -1.]),
#   (17, 3, False): array([-1.,  1.]),
#   (21, 10, True): array([ 1., -1.]),
#   (17, 6, False): array([-1., -1.]),
#   (18, 6, False): array([ 1., -1.]),
#   (8, 7, False): array([ 1., -1.]),
#   (11, 1, False): array([-1., -1.]),
#   (18, 1, False): array([-1., -1.]),
#   (9, 10, False): array([ 1., -1.]),
#   (13, 4, False): array([-1., -1.]),
#   (19, 6, False): array([ 0., -1.]),
#   (12, 9, False): array([-1.,  1.]),
#   (16, 9, False): array([ 0., -1.]),
#   (20, 9, False): array([ 1., -1.]),
#   (13, 2, True): array([-1.,  0.]),
#   (5, 10, False): array([-1., -1.]),
#   (6, 7, False): array([-1.,  1.]),
#   (19, 2, False): array([-1., -1.]),
#   (13, 1, False): array([-1., -1.]),
#   (21, 2, True): array([1., 0.]),
#   (8, 1, False): array([ 0., -1.]),
#   (16, 1, False): array([ 0., -1.]),
#   (18, 5, False): array([ 1., -1.]),
#   (14, 3, False): array([1., 1.]),
#   (21, 3, False): array([ 1., -1.]),
#   (8, 9, False): array([ 1., -1.]),
#   (18, 9, False): array([-1., -1.]),
#   (20, 6, False): array([ 1., -1.]),
#   (7, 7, False): array([-1., -1.]),
#   (17, 7, False): array([ 1., -1.]),
#   (5, 4, False): array([0., 1.]),
#   (11, 4, False): array([-1., -1.]),
#   (16, 4, False): array([ 0., -1.]),
#   (20, 4, False): array([ 1., -1.]),
#   (14, 8, False): array([-1., -1.]),
#   (21, 8, False): array([ 1., -1.]),
#   (13, 8, False): array([-1., -1.]),
#   (19, 1, False): array([ 1., -1.]),
#   (12, 2, False): array([-1., -1.]),
#   (11, 7, False): array([-1., -1.]),
#   (21, 7, True): array([0., 1.]),
#   (12, 1, False): array([-1., -1.]),
#   (15, 4, False): array([ 1., -1.]),
#   (17, 4, False): array([-1.,  1.]),
#   (21, 4, False): array([ 1., -1.]),
#   (8, 5, False): array([0., 1.]),
#   (12, 8, False): array([-1., -1.]),
#   (21, 3, True): array([ 1., -1.]),
#   (21, 4, True): array([ 1., -1.]),
#   (17, 8, False): array([-1., -1.]),
#   (12, 9, True): array([ 1., -1.]),
#   (15, 9, True): array([0., 0.]),
#   (15, 9, False): array([-1., -1.]),
#   (12, 7, False): array([-1., -1.]),
#   (17, 1, False): array([-1., -1.]),
#   (11, 8, False): array([-1., -1.]),
#   (4, 10, False): array([-1., -1.]),
#   (10, 6, False): array([-1., -1.]),
#   (7, 1, False): array([-1., -1.]),
#   (20, 1, False): array([ 1., -1.]),
#   (9, 2, False): array([ 1., -1.]),
#   (10, 2, False): array([ 1., -1.]),
#   (17, 2, False): array([-1., -1.]),
#   (6, 10, False): array([-1.,  1.]),
#   (14, 6, False): array([1., 1.]),
#   (13, 4, True): array([ 0., -1.]),
#   (17, 9, True): array([0., 1.]),
#   (13, 9, False): array([-1., -1.]),
#   (14, 1, False): array([-1., -1.]),
#   (7, 4, False): array([ 1., -1.]),
#   (19, 5, False): array([-1.,  1.]),
#   (11, 3, False): array([-1.,  1.]),
#   (11, 5, False): array([1., 1.]),
#   (14, 5, False): array([-1., -1.]),
#   (21, 9, True): array([ 1., -1.]),
#   (7, 8, False): array([ 0., -1.]),
#   (10, 8, False): array([-1.,  1.]),
#   (13, 6, False): array([ 1., -1.]),
#   (19, 10, True): array([1., 0.]),
#   (20, 5, False): array([ 1., -1.]),
#   (18, 7, True): array([ 0., -1.]),
#   (20, 10, True): array([ 1., -1.]),
#   (14, 9, True): array([0., 1.]),
#   (14, 9, False): array([-1., -1.]),
#   (19, 9, False): array([ 1., -1.]),
#   (13, 5, False): array([ 1., -1.]),
#   (6, 2, False): array([ 0., -1.]),
#   (18, 3, False): array([ 1., -1.]),
#   (10, 1, False): array([-1., -1.]),
#   (15, 1, False): array([-1., -1.]),
#   (9, 9, False): array([0., 0.]),
#   (11, 9, False): array([-1.,  1.]),
#   (17, 9, False): array([0., 0.]),
#   (19, 8, True): array([ 0., -1.]),
#   (14, 10, False): array([-1., -1.]),
#   (14, 2, False): array([-1., -1.]),
#   (20, 2, True): array([1., 1.]),
#   (6, 4, False): array([0., 1.]),
#   (18, 8, False): array([0., 1.]),
#   (19, 8, False): array([ 1., -1.]),
#   (15, 6, False): array([ 1., -1.]),
#   (9, 5, False): array([-1.,  0.]),
#   (19, 6, True): array([ 1., -1.]),
#   (21, 6, True): array([1., 1.]),
#   (6, 1, False): array([ 0., -1.]),
#   (21, 8, True): array([ 1., -1.]),
#   (16, 8, False): array([-1., -1.]),
#   (7, 6, False): array([ 0., -1.]),
#   (16, 1, True): array([ 0., -1.]),
#   (18, 1, True): array([ 0., -1.]),
#   (21, 5, False): array([ 1., -1.]),
#   (10, 3, False): array([ 1., -1.]),
#   (18, 8, True): array([1., 0.]),
#   (6, 9, False): array([ 0., -1.]),
#   (14, 10, True): array([-1., -1.]),
#   (15, 8, False): array([-1., -1.]),
#   (12, 4, False): array([1., 1.]),
#   (18, 4, False): array([ 1., -1.]),
#   (7, 5, False): array([1., 0.]),
#   (18, 2, True): array([0., 1.]),
#   (6, 6, False): array([-1., -1.]),
#   (9, 8, False): array([-1., -1.]),
#   (21, 1, False): array([ 0., -1.]),
#   (9, 6, False): array([ 1., -1.]),
#   (18, 6, True): array([ 0., -1.]),
#   (14, 8, True): array([ 0., -1.]),
#   (16, 4, True): array([ 0., -1.]),
#   (7, 2, False): array([ 0., -1.]),
#   (21, 1, True): array([ 1., -1.]),
#   (8, 4, False): array([0., 1.]),
#   (19, 4, True): array([1., 0.]),
#   (13, 10, True): array([-1., -1.]),
#   (16, 5, True): array([ 1., -1.]),
#   (12, 3, True): array([0., 1.]),
#   (12, 3, False): array([-1., -1.]),
#   (5, 3, False): array([-1., -1.]),
#   (14, 6, True): array([ 1., -1.]),
#   (21, 5, True): array([1., 0.]),
#   (19, 7, False): array([ 1., -1.]),
#   (18, 5, True): array([ 0., -1.]),
#   (16, 2, True): array([-1.,  0.]),
#   (9, 3, False): array([ 1., -1.]),
#   (19, 3, False): array([1., 1.]),
#   (5, 8, False): array([0., 1.]),
#   (16, 8, True): array([1., 0.]),
#   (14, 2, True): array([ 0., -1.]),
#   (15, 7, False): array([1., 1.]),
#   (4, 8, False): array([ 0., -1.]),
#   (6, 3, False): array([ 0., -1.]),
#   (17, 2, True): array([ 0., -1.]),
#   (20, 3, True): array([1., 1.]),
#   (12, 7, True): array([0., 1.]),
#   (15, 7, True): array([1., 0.]),
#   (15, 10, True): array([ 0., -1.]),
#   (5, 2, False): array([ 0., -1.]),
#   (15, 5, True): array([ 0., -1.]),
#   (5, 9, False): array([-1., -1.]),
#   (18, 3, True): array([ 1., -1.]),
#   (16, 10, True): array([0., 1.]),
#   (15, 2, True): array([ 1., -1.]),
#   (9, 1, False): array([-1., -1.]),
#   (10, 10, False): array([-1.,  1.]),
#   (20, 1, True): array([-1.,  0.]),
#   (18, 9, True): array([-1.,  0.]),
#   (20, 9, True): array([1., 0.]),
#   (20, 7, True): array([1., 0.]),
#   (17, 1, True): array([0., 1.]),
#   (6, 8, False): array([-1., -1.]),
#   (14, 4, True): array([1., 0.]),
#   (5, 7, False): array([1., 1.]),
#   (16, 7, True): array([0., 1.]),
#   (5, 6, False): array([0., 1.]),
#   (19, 5, True): array([0., 0.]),
#   (13, 5, True): array([-1.,  0.]),
#   (19, 2, True): array([1., 0.]),
#   (10, 4, False): array([-1., -1.]),
#   (15, 4, True): array([-1.,  0.]),
#   (21, 9, False): array([ 1., -1.]),
#   (6, 5, False): array([ 0., -1.]),
#   (19, 3, True): array([1., 0.]),
#   (14, 3, True): array([1., 1.]),
#   (10, 9, False): array([ 0., -1.]),
#   (10, 7, False): array([ 0., -1.]),
#   (17, 7, True): array([ 0., -1.]),
#   (13, 3, True): array([0., 1.]),
#   (4, 9, False): array([-1.,  0.]),
#   (20, 5, True): array([1., 0.]),
#   (16, 3, True): array([1., 0.]),
#   (4, 6, False): array([-1.,  0.]),
#   (4, 2, False): array([0., 1.])})
